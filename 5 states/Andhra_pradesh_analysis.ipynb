# %% [markdown]
# # **ML on Andhra Pradesh Data**

# %%
import pandas as pd

# %%
data = pd.read_excel("Andhra_Pradesh.xlsx",sheet_name="Sheet1")

# %%
data.head()
# Out:
#    Unnamed: 0           SITE_ID WRIS ID     LATITUDE    LONGITUDE SITE_TYPE  \
# 0         339  W135900077460001  W04180   13°59'0" N   77°46'0" E  Dug Well
# 1         340  W135900077460001  W04180   13°59'0" N   77°46'0" E  Dug Well
# 2         341  W135900077460001  W04180   13°59'0" N   77°46'0" E  Dug Well
# 3         342  W135830077524001  W04183  13°58'30" N  77°52'40" E  Dug Well
# 4         343  W135830077524001  W04183  13°58'30" N  77°52'40" E  Dug Well
#
#        STATE_NAME DISTRICT_NAME TAHSIL_NAME  BLOCK_NAME  ... FLUORIDE   SAR  \
# 0  Andhra Pradesh     Anantapur  Amarapuram  Amarapuram  ...      2.2   5.1
# 1  Andhra Pradesh     Anantapur  Amarapuram  Amarapuram  ...      1.2    ND
# 2  Andhra Pradesh     Anantapur  Amarapuram  Amarapuram  ...     3.83  3.65
# 3  Andhra Pradesh     Anantapur  Amarapuram  Amarapuram  ...      3.8   6.1
# 4  Andhra Pradesh     Anantapur  Amarapuram  Amarapuram  ...      2.1  2.27
#
#    RSC  SiO2 PO4 TDS Turbidity  %Na Arsenic LR. No
# 0   ND   NaN NaN NaN       NaN  NaN     NaN    NaN
# 1    0   NaN NaN NaN       NaN  NaN     NaN    NaN
# 2  1.6   NaN NaN NaN       NaN  NaN     NaN    NaN
# 3  5.5   NaN NaN NaN       NaN  NaN     NaN    NaN
# 4   ND   NaN NaN NaN       NaN  NaN     NaN    NaN
#
# [5 rows x 38 columns]

# %%
data = data.filter(['PH','EC','TOT_ALKALINITY','CA','MG','NA','BICARBONATE','FLUORIDE'], axis=1)

# %%
data.head()
# Out:
#      PH    EC TOT_ALKALINITY  CA     MG   NA BICARBONATE FLUORIDE
# 0  7.83  2000         314.75  66  70.59  250         384      2.2
# 1  7.61   674            BDL  ND    BDL   ND          ND      1.2
# 2  8.17   786         240.16  24  24.34  106         293     3.83
# 3   7.6   990         440.16  24  25.56  180         537      3.8
# 4  7.64   862         235.25  62  20.74   81         287      2.1

# %%
data = data.dropna(axis=0)
data.count()
# Out:
# PH                3937
# EC                3937
# TOT_ALKALINITY    3937
# CA                3937
# MG                3937
# NA                3937
# BICARBONATE       3937
# FLUORIDE          3937
# dtype: int64
