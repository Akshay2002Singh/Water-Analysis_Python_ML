# %% [markdown]
# # Filtering data to seperate 5 states

# %%
import pandas as pd

# %%
all_data = pd.read_excel("GWQ_2010-2018.xlsx",sheet_name="Sheet1")

# %%
all_data.shape
# Out:
# (85197, 37)

# %%
all_data = all_data.dropna(subset=["FLUORIDE"])

# %%
all_data.shape
# Out:
# (83992, 37)

# %%
all_data.head()
# Out:
#             SITE_ID WRIS ID   LATITUDE  LONGITUDE SITE_TYPE  \
# 0  W115159092441001  W23881  11.866389  92.736111  Dug Well
# 1               New  W38814  12.186944  92.791667  Dug Well
# 2  W123014092513301  W24095  12.503889  92.859167  Dug Well
# 3  W123129092581301  W24112  12.524722  92.970278  Dug Well
# 4  W123030092573801  W24098  12.508333  92.960556  Dug Well
#
#             STATE_NAME  DISTRICT_NAME     TAHSIL_NAME       BLOCK_NAME  \
# 0  Andaman And Nicobar  A & N Islands      Ferrargunj    South Andaman
# 1  Andaman And Nicobar  A & N Islands  Middle Andaman  Baratang Island
# 2  Andaman And Nicobar  A & N Islands  Middle Andaman       Mayabunder
# 3  Andaman And Nicobar  A & N Islands  Middle Andaman       Mayabunder
# 4  Andaman And Nicobar  A & N Islands  Middle Andaman       Mayabunder
#
#                   SITE_NAME  ... FLUORIDE  SAR  RSC   SiO2  PO4      TDS  \
# 0        Shoal  Bay– 15 No.  ...     0.37  NaN  NaN  13.97  NaN  217.748
# ...

# %%
Rajasthan = all_data.loc[all_data['STATE_NAME']=='Rajasthan']

# %%
Rajasthan
# Out:
#                 SITE_ID WRIS ID   LATITUDE   LONGITUDE SITE_TYPE STATE_NAME  \
# 63518  W260200075060001  W13591  26°2'0" N   75°6'0" E  Dug Well  Rajasthan
# 63519  W260200075060001  W13591  26°2'0" N   75°6'0" E  Dug Well  Rajasthan
# 63520  W260200075060001  W13591  26°2'0" N   75°6'0" E  Dug Well  Rajasthan
# 63521  W260200075060001  W13591  26°2'0" N   75°6'0" E  Dug Well  Rajasthan
# 63522  W260200075060001  W13591  26°2'0" N   75°6'0" E  Dug Well  Rajasthan
# ...                 ...     ...        ...         ...       ...        ...
# 68939  W240500073510001  W14586  24°5'0" N  73°51'0" E  Dug Well  Rajasthan
# 68940  W240500073510001  W14586  24°5'0" N  73°51'0" E  Dug Well  Rajasthan
# 68941  W240500073510001  W14586  24°5'0" N  73°51'0" E  Dug Well  Rajasthan
# 68942  W240500073510001  W14586  24°5'0" N  73°51'0" E  Dug Well  Rajasthan
# 68943  W240500073510001  W14586  24°5'0" N  73°51'0" E  Dug Well  Rajasthan
#
# ...

# %%
# done
# Rajasthan.to_excel("Rajasthan.xlsx",sheet_name='Sheet1')

# %%
Andhra_Pradesh = all_data.loc[all_data['STATE_NAME']=='Andhra Pradesh']
Andhra_Pradesh
# Out:
#                SITE_ID WRIS ID     LATITUDE    LONGITUDE   SITE_TYPE  \
# 339   W135900077460001  W04180   13°59'0" N   77°46'0" E    Dug Well
# 340   W135900077460001  W04180   13°59'0" N   77°46'0" E    Dug Well
# 341   W135900077460001  W04180   13°59'0" N   77°46'0" E    Dug Well
# 342   W135830077524001  W04183  13°58'30" N  77°52'40" E    Dug Well
# 343   W135830077524001  W04183  13°58'30" N  77°52'40" E    Dug Well
# ...                ...     ...          ...          ...         ...
# 4953  W163200081390001  W05217   16°32'0" N   81°39'0" E    Dug Well
# 4954  W163200081390001  W05217   16°32'0" N   81°39'0" E    Dug Well
# 4955  W163200081390001  W05217   16°32'0" N   81°39'0" E    Dug Well
# 4956  W163200081390001  W05217    16.533333        81.65  MONITORING
# 4957  W163200081390001  W05217      16.5333        81.65  MONITORING
#
#           STATE_NAME  DISTRICT_NAME   TAHSIL_NAME    BLOCK_NAME  \
# 339   Andhra Pradesh      Anantapur    Amarapuram    Amarapuram
# ...

# %%
# done
# Andhra_Pradesh.to_excel("Andhra_Pradesh.xlsx",sheet_name='Sheet1')

# %%
West_Bengal = all_data.loc[all_data['STATE_NAME']=='West Bengal']
West_Bengal
# Out:
#                 SITE_ID WRIS ID LATITUDE LONGITUDE SITE_TYPE   STATE_NAME  \
# 81154               New  W40678    22.87     86.78  Dug well  West Bengal
# 81155  W232514087063701  W10143     23.4     87.11  Dug well  West Bengal
# 81156               New  W40679    23.31     87.11  Dug well  West Bengal
# 81157               New  W40680    23.31     86.96  Dug well  West Bengal
# 81158               New  W40681    23.07     86.89  Dug well  West Bengal
# ...                 ...     ...      ...       ...       ...          ...
# 85192               New  W40943    22.51     87.33  Dug Well  West Bengal
# 85193  W220857087092501  W10716    22.18     87.16  Dug Well  West Bengal
# 85194               New  W40944    22.58     87.52  Dug Well  West Bengal
# 85195               New  W40945    22.47     87.02  Dug Well  West Bengal
# 85196               New  W40946    22.61     86.81  Dug Well  West Bengal
#
#        DISTRICT_NAME  TAHSIL_NAME      BLOCK_NAME                SITE_NAME  \
# ...

# %%
# done
# West_Bengal.to_excel("West_Bengal.xlsx",sheet_name='Sheet1')

# %%
Telangana = all_data.loc[all_data['STATE_NAME']=='Telangana']
Telangana
# Out:
#                 SITE_ID WRIS ID     LATITUDE    LONGITUDE   SITE_TYPE  \
# 72970  W192200079170001  W03811   19°22'0" N   79°17'0" E    Dug Well
# 72971  W193816078303001  W26159  19°38'16" N  78°30'30" E    Dug Well
# 72972  W193816078303001  W26159  19°38'16" N  78°30'30" E    Dug Well
# 72973  W193816078303001  W26159  19°38'16" N  78°30'30" E    Dug Well
# 72974  W193816078303001  W26159    19.637778    78.508333  MONITORING
# ...                 ...     ...          ...          ...         ...
# 75882  W172859079462301  W25563    17.483056    79.773056  MONITORING
# 75883  W172859079462301  W25563      17.4831      79.7731  MONITORING
# 75884               New  W40538    17.830556    79.595278  MONITORING
# 75885               New  W40538      17.8306      79.5953  MONITORING
# 75886               New  W37730    17.800169    79.597134    Dug Well
#
#       STATE_NAME DISTRICT_NAME    TAHSIL_NAME     BLOCK_NAME  \
# 72970  Telangana      Adilabad       Asifabad       Asifabad
# ...

# %%
# done
# Telangana.to_excel("Telangana.xlsx",sheet_name='Sheet1')

# %%
Tamil_Nadu = all_data.loc[all_data['STATE_NAME']=='Tamil Nadu']
Tamil_Nadu
# Out:
#                 SITE_ID WRIS ID    LATITUDE    LONGITUDE SITE_TYPE  \
# 68944               New  W40047      11.081      79.1407  Dug Well
# 68945               New  W40048     11.1401      79.0786  Dug Well
# 68946               New  W40049        11.2        79.32  Dug Well
# 68947               New  W40045      11.155      79.1901  Dug Well
# 68948               New  W40050     11.1401      79.0786  Dug Well
# ...                 ...     ...         ...          ...       ...
# 72965  W093500077571501  W02916   9°35'0" N  77°57'15" E  Dug Well
# 72966  W093500077571501  W02916   9°35'0" N  77°57'15" E  Dug Well
# 72967  W093749077383001  W02924  9°37'49" N  77°38'30" E  Dug Well
# 72968  W093749077383001  W02924  9°37'49" N  77°38'30" E  Dug Well
# 72969  W093749077383001  W02924  9°37'49" N  77°38'30" E  Dug Well
#
#        STATE_NAME DISTRICT_NAME   TAHSIL_NAME    BLOCK_NAME  \
# 68944  Tamil Nadu      Ariyalur      Ariyalur      Ariyalur
# ...

# %%
# done
# Tamil_Nadu.to_excel("Tamil_Nadu.xlsx",sheet_name='Sheet1')
