# %% [markdown]
# # **ML on Andhra Pradesh Data**

# %%
import pandas as pd
import numpy as np

# %%
# data = pd.read_excel("Tamil_Nadu.xlsx",sheet_name="Sheet1")

# %%
# data.head()
# Out:
#    Unnamed: 0 SITE_ID WRIS ID LATITUDE LONGITUDE SITE_TYPE  STATE_NAME  \
# 0       68944     New  W40047   11.081   79.1407  Dug Well  Tamil Nadu
# 1       68945     New  W40048  11.1401   79.0786  Dug Well  Tamil Nadu
# 2       68946     New  W40049     11.2     79.32  Dug Well  Tamil Nadu
# 3       68947     New  W40045   11.155   79.1901  Dug Well  Tamil Nadu
# 4       68948     New  W40050  11.1401   79.0786  Dug Well  Tamil Nadu
#
#   DISTRICT_NAME   TAHSIL_NAME   BLOCK_NAME  ...  FLUORIDE SAR RSC  SiO2 PO4  \
# 0      Ariyalur      Ariyalur     Ariyalur  ...      0.05   0   0     0   0
# 1      Ariyalur      Ariyalur     Ariyalur  ...       0.9   0   0     0   0
# 2      Ariyalur   Jayamkondam  Jayankondam  ...      0.05   0   0     0   0
# 3      Ariyalur      Sendurai     Ariyalur  ...      0.54   0   0     0   0
# 4      Ariyalur  T.Kallupatti     Ariyalur  ...  2.432369   0   0     0   0
#
#       TDS Turbidity %Na Arsenic LR. No
# 0   65.52         0           0    0.0
# ...

# %%
# data = data.filter(['PH','EC','TOT_ALKALINITY','CA','MG','NA','BICARBONATE','FLUORIDE'], axis=1)

# %%
# data.to_excel("Tamil_Nadu_filter.xlsx",sheet_name='Sheet1',index=False)

# %%
data = pd.read_excel("Tamil_Nadu_filter.xlsx",sheet_name="Sheet1")

# %%
data.head()
# Out:
#     PH      EC  TOT_ALKALINITY     CA        MG      NA  BICARBONATE  FLUORIDE
# 0  5.8   104.0             0.0    8.0    7.2912    8.28       36.612  0.050000
# 1  7.4  1610.0             0.0   64.0   34.0256  225.40      280.692  0.900000
# 2  7.5  3290.0             0.0   48.0   48.6080  419.98      854.280  0.050000
# 3  7.1  2610.0             0.0  280.0   19.4432  260.82      384.426  0.540000
# 4  7.7  2260.0             0.0   84.0  126.3808  174.80      579.690  2.432369

# %%
data = data.dropna(axis=0)
data.count()
# Out:
# PH                2123
# EC                2123
# TOT_ALKALINITY    2123
# CA                2123
# MG                2123
# NA                2123
# BICARBONATE       2123
# FLUORIDE          2123
# dtype: int64

# %%
data = data.astype(float)

# %%
data.corr()
# Out:
#                       PH        EC  TOT_ALKALINITY        CA        MG  \
# PH              1.000000 -0.028375        0.353303 -0.169899 -0.017778
# EC             -0.028375  1.000000        0.096201  0.599111  0.252639
# TOT_ALKALINITY  0.353303  0.096201        1.000000 -0.095438 -0.094442
# CA             -0.169899  0.599111       -0.095438  1.000000  0.196890
# MG             -0.017778  0.252639       -0.094442  0.196890  1.000000
# NA              0.019459  0.850068        0.146703  0.396434  0.149859
# BICARBONATE     0.051749  0.427900        0.282386  0.194526  0.106181
# FLUORIDE       -0.021323  0.023073       -0.010814 -0.011964 -0.003380
#
#                       NA  BICARBONATE  FLUORIDE
# PH              0.019459     0.051749 -0.021323
# EC              0.850068     0.427900  0.023073
# TOT_ALKALINITY  0.146703     0.282386 -0.010814
# CA              0.396434     0.194526 -0.011964
# MG              0.149859     0.106181 -0.003380
# ...

# %%
data['Bin_Fluoride'] = np.where( data['FLUORIDE'] >= 1,1,0)
data['Bin_Fluoride'].value_counts()
# Out:
# 0    1315
# 1     808
# Name: Bin_Fluoride, dtype: int64
